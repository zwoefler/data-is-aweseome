# %%
from tabula import read_pdf
import pandas as pd
import seaborn as sns
import re
import matplotlib.pyplot as plt

# %%
def get_emissions_table_from_page_1353():
    """Page 1353 from the PDF document, is 1335 IN the document!"""
    df = read_pdf("ipcc_wg3_ar5_full.pdf", pages=1353)[0]
    return df

# %%
df = get_emissions_table_from_page_1353()
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Projects/data-is-awesome/DATA_PROJECTS/co2-emissions/Env/lib/python3.8/site-packages/tabula/backend.py:122, in SubprocessTabula.call_tabula_java(self, options, path)
#     121 try:
# --> 122     result = subprocess.run(
#     123         args,
#     124         stdout=subprocess.PIPE,
#     125         stderr=subprocess.PIPE,
#     126         stdin=subprocess.DEVNULL,
#     127         check=True,
#     128     )
#     129     if result.stderr:
#
# File /usr/lib/python3.8/subprocess.py:493, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     491     kwargs['stderr'] = PIPE
# --> 493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
#
# File /usr/lib/python3.8/subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
#     860                         startupinfo, creationflags, shell,
#     861                         p2cread, p2cwrite,
#     862                         c2pread, c2pwrite,
#     863                         errread, errwrite,
#     864                         restore_signals, start_new_session)
#     865 except:
#     866     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.8/subprocess.py:1704, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1703         err_msg = os.strerror(errno_num)
# -> 1704     raise child_exception_type(errno_num, err_msg, err_filename)
#    1705 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'java'
#
# During handling of the above exception, another exception occurred:
#
# JavaNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = get_emissions_table_from_page_1353()
#
# Cell In[5], line 3, in get_emissions_table_from_page_1353()
#       1 def get_emissions_table_from_page_1353():
#       2     """Page 1353 from the PDF document, is 1335 IN the document!"""
# ----> 3     df = read_pdf("ipcc_wg3_ar5_full.pdf", pages=1353)[0]
#       4     return df
#
# File ~/Projects/data-is-awesome/DATA_PROJECTS/co2-emissions/Env/lib/python3.8/site-packages/tabula/io.py:400, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     397     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     399 try:
# --> 400     output = _run(
#     401         tabula_options,
#     402         java_options,
#     403         path,
#     404         encoding=encoding,
#     405         force_subprocess=force_subprocess,
#     406     )
#     407 finally:
#     408     if temporary:
#
# File ~/Projects/data-is-awesome/DATA_PROJECTS/co2-emissions/Env/lib/python3.8/site-packages/tabula/io.py:86, in _run(options, java_options, path, encoding, force_subprocess)
#      83 elif set(java_options) - IGNORED_JAVA_OPTIONS:
#      84     logger.warning("java_options is ignored until rebooting the Python process.")
# ---> 86 return _tabula_vm.call_tabula_java(options, path)
#
# File ~/Projects/data-is-awesome/DATA_PROJECTS/co2-emissions/Env/lib/python3.8/site-packages/tabula/backend.py:133, in SubprocessTabula.call_tabula_java(self, options, path)
#     131     return result.stdout.decode(self.encoding)
#     132 except FileNotFoundError:
# --> 133     raise JavaNotFoundError(JAVA_NOT_FOUND_ERROR)
#     134 except subprocess.CalledProcessError as e:
#     135     logger.error(f"Error from tabula-java:\n{e.stderr.decode(self.encoding)}\n")
#
# JavaNotFoundError: `java` command is not found from this Python process.Please ensure Java is installed and PATH is set for `java`

# %%
df
# Out:
#                                           Options    Direct emissions
# 0                                             NaN  Min / Median / Max  \
# 1   Currently Commercially Available Technologies                 NaN
# 2                                       Coal — PC     670 / 760 / 870
# 3                            Gas — Combined Cycle     350 / 370 / 490
# 4                              Biomass — cofiring            n. a. ii
# 5                             Biomass — dedicated            n. a. ii
# 6                                      Geothermal                   0
# 7                                      Hydropower                   0
# 8                                         Nuclear                   0
# 9                        Concentrated Solar Power                   0
# 10                             Solar PV — rooftop                   0
# 11                             Solar PV — utility                   0
# 12                                   Wind onshore                   0
# 13                                  Wind offshore                   0
# 14                    Pre-commercial Technologies                 NaN
# 15                           CCS — Coal — Oxyfuel       14 / 76 / 110
# 16                                CCS — Coal — PC      95 / 120 / 140
# 17                              CCS — Coal — IGCC     100 / 120 / 150
# 18                     CCS — Gas — Combined Cycle        30 / 57 / 98
# 19                                          Ocean                   0
#
#    Infrastructure & supply\rchain emissions
# 0                            Typical values  \
# 1                                       NaN
# 2                                       9.6
# 3                                       1.6
# 4                                         –
# 5                                       210
# 6                                        45
# 7                                        19
# 8                                        18
# 9                                        29
# 10                                       42
# 11                                       66
# 12                                       15
# 13                                       17
# 14                                      NaN
# 15                                       17
# 16                                       28
# 17                                      9.9
# 18                                      8.9
# 19                                       17
#
#    Biogenic CO2 emissions\rand albedo effect Methane emissions
# 0                         Min / Median / Max               NaN  \
# 1                                        NaN               NaN
# 2                                          0                47
# 3                                          0                91
# 4                                          –                 –
# 5                                         27                 0
# 6                                          0                 0
# 7                                          0                88
# 8                                          0                 0
# 9                                          0                 0
# 10                                         0                 0
# 11                                         0                 0
# 12                                         0                 0
# 13                                         0                 0
# 14                                       NaN               NaN
# 15                                         0                67
# 16                                         0                68
# 17                                         0                62
# 18                                         0               110
# 19                                         0                 0
#
#    Lifecycle emissions\r(incl. albedo effect)
# 0                                         NaN
# 1                                         NaN
# 2                             740 / 820 / 910
# 3                             410 / 490 / 650
# 4                          620 / 740 / 890iii
# 5                           130 / 230 / 420iv
# 6                               6.0 / 38 / 79
# 7                             1.0 / 24 / 2200
# 8                              3.7 / 12 / 110
# 9                               8.8 / 27 / 63
# 10                               26 / 41 / 60
# 11                              18 / 48 / 180
# 12                              7.0 / 11 / 56
# 13                              8.0 / 12 / 35
# 14                                        NaN
# 15                            100 / 160 / 200
# 16                            190 / 220 / 250
# 17                            170 / 200 / 230
# 18                             94 / 170 / 340
# 19                              5.6 / 17 / 28

# %%
def get_lifecycle_emissions_df(df):
    split_df = df["Lifecycle emissions\r(incl. albedo effect)"].str.split('/', expand=True)
    split_df.columns = ["Min", "Median", "Max"]
    split_df["Max"] = split_df["Max"].str.extract('(\d+)')
    split_df = split_df.apply(pd.to_numeric, errors="coerce")
    return pd.concat([df["Options"], split_df], axis=1).dropna(how="all")

# %%
split_df = get_lifecycle_emissions_df(df)

# %%
split_df
# Out:
#                                           Options    Min  Median     Max
# 1   Currently Commercially Available Technologies    NaN     NaN     NaN
# 2                                       Coal — PC  740.0   820.0   910.0
# 3                            Gas — Combined Cycle  410.0   490.0   650.0
# 4                              Biomass — cofiring  620.0   740.0   890.0
# 5                             Biomass — dedicated  130.0   230.0   420.0
# 6                                      Geothermal    6.0    38.0    79.0
# 7                                      Hydropower    1.0    24.0  2200.0
# 8                                         Nuclear    3.7    12.0   110.0
# 9                        Concentrated Solar Power    8.8    27.0    63.0
# 10                             Solar PV — rooftop   26.0    41.0    60.0
# 11                             Solar PV — utility   18.0    48.0   180.0
# 12                                   Wind onshore    7.0    11.0    56.0
# 13                                  Wind offshore    8.0    12.0    35.0
# 14                    Pre-commercial Technologies    NaN     NaN     NaN
# 15                           CCS — Coal — Oxyfuel  100.0   160.0   200.0
# 16                                CCS — Coal — PC  190.0   220.0   250.0
# 17                              CCS — Coal — IGCC  170.0   200.0   230.0
# 18                     CCS — Gas — Combined Cycle   94.0   170.0   340.0
# 19                                          Ocean    5.6    17.0    28.0

# %%
availabl_technology_df = split_df.loc[2:13]

# %%
availabl_technology_df
# Out:
#                      Options    Min  Median     Max
# 2                  Coal — PC  740.0   820.0   910.0
# 3       Gas — Combined Cycle  410.0   490.0   650.0
# 4         Biomass — cofiring  620.0   740.0   890.0
# 5        Biomass — dedicated  130.0   230.0   420.0
# 6                 Geothermal    6.0    38.0    79.0
# 7                 Hydropower    1.0    24.0  2200.0
# 8                    Nuclear    3.7    12.0   110.0
# 9   Concentrated Solar Power    8.8    27.0    63.0
# 10        Solar PV — rooftop   26.0    41.0    60.0
# 11        Solar PV — utility   18.0    48.0   180.0
# 12              Wind onshore    7.0    11.0    56.0
# 13             Wind offshore    8.0    12.0    35.0

# %%
amount_options = len(availabl_technology_df["Options"])
ticks_every = 5
max_y = amount_options * ticks_every
y_steps_list = list(range(ticks_every, max_y + 1, ticks_every))

# %%
availabl_technology_df.to_csv("co2_emissions.csv", index=False)

# %%
yoo_df = pd.read_csv("co2_emissions.csv")

# %%
for i, value in enumerate(y_steps_list):
    create_bar(availabl_technology_df.iloc[i]["Min"], availabl_technology_df.iloc[i]["Max"], value)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# 55
# 60

# %%
def create_bar(min_value, max_value, y_step_value):
    return ax.broken_barh([(min_value, (max_value - min_value))], (y_step_value - 1.5, 3))

# %%
def plot_co2_emissions(df, labels_column, ticks_every = 5):
    amount_options = len(df[labels_column])
    max_y = amount_options * ticks_every
    y_steps_list = list(range(ticks_every, max_y + 1, ticks_every))

    plt.style.use("seaborn")
    fig, ax = plt.subplots()
    for i, value in enumerate(y_steps_list):
        min_value = df.iloc[i]["Min"]
        max_value = df.iloc[i]["Max"]
        ax.broken_barh([(min_value, (max_value - min_value))], (value - 0.5, 1))
        ax.scatter(df.iloc[i]["Median"], value, color="yellow")
        #create_bar(df.iloc[i]["Min"], df.iloc[i]["Max"], value)
    #ax.broken_barh([(740, (910-740))], (3.5, 3))
    ax.set_ylim(0, max_y + ticks_every)
    ax.set_yticks(y_steps_list, labels=availabl_technology_df["Options"])
    ax.set_xlim(0, 1000)
    ax.set_xlabel('CO2 Emissions in gCO2/KWh')

# %%
plot_co2_emissions(yoo_df, "Options")
# Out:
# /tmp/ipykernel_8879/1479958981.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
plt.style.use("seaborn")
fig, ax = plt.subplots()
ax.broken_barh([(740, (910-740))], (3.5, 3))
ax.set_ylim(0, max_y + ticks_every)
ax.set_yticks(y_steps_list, labels=availabl_technology_df["Options"])
ax.set_xlim(0, 1000)
ax.set_xlabel('CO2 Emissions')
# Out:
# /tmp/ipykernel_8879/194743020.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
# Text(0.5, 0, 'CO2 Emissions')
